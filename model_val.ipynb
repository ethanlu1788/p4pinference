# %%
from ultralytics import YOLO

# Load PyTorch model
model = YOLO("models/best_openvino_model")

# Validate on your custom dataset
metrics = model.val(data="val/val.yaml")

print(metrics.box.map)    # mAP 0.5:0.95
print(metrics.box.map50)  # mAP@.50
print(metrics.box.map75)  # mAP@.75
print(metrics.box.maps)   # mAP for each class
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.196  Python-3.11.7 torch-2.8.0+cpu CPU (AMD Ryzen 7 5800X 8-Core Processor)
# Loading models/best_openvino_model for OpenVINO inference...
# Using OpenVINO LATENCY mode for batch=1 inference on CPU...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access  (ping: 0.10.0 ms, read: 555.9125.0 MB/s, size: 1200.7 KB)
# val: Scanning C:\Users\ethan\Documents\GitHub\p4pinference\val\labels.cache... 1585 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1585/1585 3.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1585/1585 5.2it/s 5:03<0.2ss
#                    all       1585       9022      0.788       0.69      0.755      0.538
# ...

# %%
# Load PyTorch model
model = YOLO("models/best_int8_openvino_model")

# Validate on your custom dataset
metrics = model.val(data="val/val.yaml")

print(metrics.box.map)    # mAP 0.5:0.95
print(metrics.box.map50)  # mAP@.50
print(metrics.box.map75)  # mAP@.75
print(metrics.box.maps)   # mAP for each class
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.196  Python-3.11.7 torch-2.8.0+cpu CPU (AMD Ryzen 7 5800X 8-Core Processor)
# Loading models/best_int8_openvino_model for OpenVINO inference...
# Using OpenVINO LATENCY mode for batch=1 inference on CPU...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access  (ping: 0.10.0 ms, read: 1020.5956.5 MB/s, size: 1552.7 KB)
# val: Scanning C:\Users\ethan\Documents\GitHub\p4pinference\val\labels.cache... 1585 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1585/1585 3.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1585/1585 5.7it/s 4:38<0.1ss
#                    all       1585       9022      0.777      0.683      0.752      0.533
# ...

# %%
# Load PyTorch model
model = YOLO("models/best.onnx")

# Validate on your custom dataset
metrics = model.val(data="val/val.yaml")

print(metrics.box.map)    # mAP 0.5:0.95
print(metrics.box.map50)  # mAP@.50
print(metrics.box.map75)  # mAP@.75
print(metrics.box.maps)   # mAP for each class
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.196  Python-3.11.7 torch-2.8.0+cpu CPU (AMD Ryzen 7 5800X 8-Core Processor)
# Loading models/best.onnx for ONNX Runtime inference...
# Using ONNX Runtime CPUExecutionProvider
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access  (ping: 0.20.2 ms, read: 825.3608.7 MB/s, size: 2298.2 KB)
# val: Scanning C:\Users\ethan\Documents\GitHub\p4pinference\val\labels.cache... 1585 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1585/1585 3.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1585/1585 5.5it/s 4:50<0.1ss
#                    all       1585       9022      0.788       0.69      0.755      0.538
#                 Person       1515       2734      0.857      0.701      0.816      0.594
# ...

# %%
# Load PyTorch model
model = YOLO("models/best_saved_model_tflite/best_float32.tflite")

# Validate on your custom dataset
metrics = model.val(data="val/val.yaml")

print(metrics.box.map)    # mAP 0.5:0.95
print(metrics.box.map50)  # mAP@.50
print(metrics.box.map75)  # mAP@.75
print(metrics.box.maps)   # mAP for each class
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.196  Python-3.11.7 torch-2.8.0+cpu CPU (AMD Ryzen 7 5800X 8-Core Processor)
# Loading models/best_saved_model_tflite/best_float32.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access  (ping: 0.10.1 ms, read: 723.071.7 MB/s, size: 1448.4 KB)
# val: Scanning C:\Users\ethan\Documents\GitHub\p4pinference\val\labels.cache... 1585 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1585/1585  0.0s
# C:\Users\ethan\anaconda3\Lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
# ...

# %%
# Load PyTorch model
model = YOLO("models/best.torchscript")

# Validate on your custom dataset
metrics = model.val(data="val/val.yaml")

print(metrics.box.map)    # mAP 0.5:0.95
print(metrics.box.map50)  # mAP@.50
print(metrics.box.map75)  # mAP@.75
print(metrics.box.maps)   # mAP for each class
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.196  Python-3.11.7 torch-2.8.0+cpu CPU (AMD Ryzen 7 5800X 8-Core Processor)
# Loading models/best.torchscript for TorchScript inference...
# val: Fast image access  (ping: 0.10.0 ms, read: 752.6183.0 MB/s, size: 1511.4 KB)
# val: Scanning C:\Users\ethan\Documents\GitHub\p4pinference\val\labels.cache... 1585 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1585/1585 3.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 0.3it/s 5:08.8ss
#                    all       1585       9022      0.788       0.69      0.755      0.538
#                 Person       1515       2734      0.857      0.701      0.816      0.594
#                   Head       1314       2427      0.948      0.724      0.854       0.62
# ...

# %%
# Load PyTorch model
model = YOLO("models/best_ncnn_model")

# Validate on your custom dataset
metrics = model.val(data="val/val.yaml")

print(metrics.box.map)    # mAP 0.5:0.95
print(metrics.box.map50)  # mAP@.50
print(metrics.box.map75)  # mAP@.75
print(metrics.box.maps)   # mAP for each class
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.196  Python-3.11.7 torch-2.8.0+cpu CPU (AMD Ryzen 7 5800X 8-Core Processor)
# Loading models/best_ncnn_model for NCNN inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# val: Fast image access  (ping: 0.10.0 ms, read: 1885.31348.6 MB/s, size: 1884.8 KB)
# val: Scanning C:\Users\ethan\Documents\GitHub\p4pinference\val\labels.cache... 1585 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1585/1585 3.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1585/1585 4.6it/s 5:43<0.2s
#                    all       1585       9022      0.788       0.69      0.755      0.538
#                 Person       1515       2734      0.857      0.701      0.816      0.594
# ...
