# %%
from ultralytics import YOLO

# Load PyTorch model
model = YOLO("models/best.pt")

# Validate on your custom dataset
metrics = model.val(data="val/val.yaml")

print(metrics.box.map)    # mAP 0.5:0.95
print(metrics.box.map50)  # mAP@.50
print(metrics.box.map75)  # mAP@.75
print(metrics.box.maps)   # mAP for each class
# Out:
# Ultralytics 8.3.196  Python-3.11.7 torch-2.8.0+cpu CPU (AMD Ryzen 7 5800X 8-Core Processor)
# YOLO11n summary (fused): 100 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 577.7113.2 MB/s, size: 1814.7 KB)
# val: Scanning C:\Users\ethan\Documents\GitHub\p4pinference\val\labels.cache... 1585 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1585/1585 1.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 100/100 0.4it/s 4:44.0ss
#                    all       1585       9022      0.694      0.648      0.662      0.445
#                 Person       1515       2734      0.818      0.858      0.878      0.694
#                   Head       1314       2427      0.893      0.851      0.886      0.678
#                Glasses        323        398      0.587       0.55      0.556      0.275
#                  Hands       1284       3212      0.783      0.768      0.808      0.522
#            Safety-vest         45         97      0.459      0.349      0.298      0.142
#                 Helmet         93        154      0.621      0.511      0.547      0.359
# Speed: 1.1ms preprocess, 40.9ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to C:\Users\ethan\Documents\GitHub\p4pinference\runs\detect\val3
# 0.44473977926287367
# 0.6621064692331954
# 0.48390420484102975
# [    0.69364     0.67769     0.27469     0.52171     0.14213     0.35859]

# %%
0
